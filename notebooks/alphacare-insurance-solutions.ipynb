# %% [markdown]
# ### 10 Academy: Artificial Intelligence Mastery
# ### AlphaCare Insurance Solutions (ACIS)
# ### Task-1: EDA

# %%
import sys

# Include the scripts and source directories in the Python path
scripts_dir = r'E:\DS+ML\AIM3\Week3\Week3\Week3.AIM3\scripts'
src_dir = r'E:\DS+ML\AIM3\Week3\Week3\Week3.AIM3\src'
txt_file_path = r"E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.txt"
csv_file_path = r"E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.csv"

# Check if the scripts directory is already in the path; if not, append it
if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)

# Check if the source directory is already in the path; if not, append it
if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
# scripts/run_task_1.py

# Importing necessary modules for data loading, preprocessing, exploratory data analysis (EDA), and visualization
from data_loader import load_data, save_to_csv
from data_preprocessing import (
    handle_missing_values,
    handle_outliers,
    detect_missing_values,
    detect_outliers
)
from eda import (
    data_summary,
    univariate_analysis,
    bivariate_analysis,
    descriptive_statistics,
    check_data_structure,
    compare_data
)
from visualization import (
    outlier_detection,
    compare_trends_over_geography,
    visualize_eda
)

# %% [markdown]
# #### Convert Data .txt to .csv

# %%
# Step 1: Load and Convert Data from Text File to CSV
try:
    df = load_data(txt_file_path)
    save_to_csv(df, csv_file_path)
    print(f"Data successfully loaded from {txt_file_path} and saved to {csv_file_path}.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File saved to E:\DS+ML\AIM3\Week3\Data\MachineLearningRating_v3.csv

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %% [markdown]
# #### Detect Missing Values and Outliers (Box_Plot)

# %%
# Show Missing Values
print("🕵️‍♀️ Missing Values:")
missing_values = detect_missing_values(df)
print(missing_values)

# Identify and Display Outliers
print("\n🕵️‍♂️ Outliers:")
outliers = detect_outliers(df)
print(outliers)

# Execute Outlier Detection Procedure
perform_outlier_detection(df)
# Out:
# 🕵️‍♀️ Missing Values:
#                          Missing Values  Percentage Missing
# Bank                             145961           14.594670
# AccountType                       40232            4.022806
# MaritalStatus                      8259            0.825819
# Gender                             9536            0.953507
# mmcode                              552            0.055195
# VehicleType                         552            0.055195
# make                                552            0.055195
# Model                               552            0.055195
# Cylinders                           552            0.055195
# cubiccapacity                       552            0.055195
# kilowatts                           552            0.055195
# bodytype                            552            0.055195
# NumberOfDoors                       552            0.055195
# VehicleIntroDate                    552            0.055195
# ...

# %% [markdown]
# #### Handling Missing Values and Outliers

# %%
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)

# Process to address missing values in the DataFrame
df = handle_missing_values(df)
logging.info('Missing values handled.')

# Process to manage outliers in the DataFrame
df = handle_outliers(df)
logging.info('Outliers managed.')
# Out:
# Dropped columns with >50.0% or 100% missing values: ['CustomValueEstimate', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet', 'NumberOfVehiclesInFleet']
# Filled missing values: Mode for categorical, Mean/Median for numerical columns.
# Capped outliers using IQR method for numerical columns.

# %% [markdown]
# #### Descriptive Statistics

# %%
# Summary Statistics
print("Summary Statistics:")
summary_stats = calculate_descriptive_statistics(df)
print(summary_stats)
# Out:
# Descriptive Statistics:
#                               count          mean            std  \
# UnderwrittenCoverID       1000098.0  1.047113e+05   63000.339700
# PolicyID                  1000098.0  7.928715e+03    5217.448901
# PostalCode                1000098.0  3.017795e+03    2643.015668
# mmcode                    1000098.0  6.005746e+07    1589.507333
# RegistrationYear          1000098.0  2.010243e+03       3.198562
# Cylinders                 1000098.0  4.000000e+00       0.000000
# cubiccapacity             1000098.0  2.472711e+03     328.973301
# kilowatts                 1000098.0  9.712713e+01      18.866700
# NumberOfDoors             1000098.0  4.000000e+00       0.000000
# SumInsured                1000098.0  1.476228e+05  225042.041685
# CalculatedPremiumPerTerm  1000098.0  6.323744e+01      83.099720
# TotalPremium              1000098.0  1.486439e+01      21.969335
# TotalClaims               1000098.0  0.000000e+00       0.000000
#
# ...

# %% [markdown]
# #### Data Structure

# %%
# Displaying the Data Structure
print("\nData Structure:")
data_structure = check_data_structure(df)

# Output the data types of each column
print(f"Data Types of Columns:\n{data_structure['column_dtypes']}")

# Output the list of categorical columns
print(f"List of Categorical Columns: {data_structure['categorical_columns']}")

# Output the list of datetime columns
print(f"List of Datetime Columns: {data_structure['datetime_columns']}")
# Out:
# Data Structure:
# Column Dtypes:
# UnderwrittenCoverID         float64
# PolicyID                    float64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                  float64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear            float64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# ...

# %% [markdown]
# #### Data Summary

# %%
# Step 4: Data Summary
data_summary(df)
# Out:
# Data Summary:
#
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  1.000098e+06
# mean          1.047113e+05  7.928715e+03  3.017795e+03  6.005746e+07
# std           6.300034e+04  5.217449e+03  2.643016e+03  1.589507e+03
# min           1.000000e+00  1.400000e+01  1.000000e+00  6.005469e+07
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           2.652605e+05  2.094250e+04  9.209500e+03  6.006066e+07
#
#        RegistrationYear  Cylinders  cubiccapacity     kilowatts  \
# count      1.000098e+06  1000098.0   1.000098e+06  1.000098e+06
# mean       2.010243e+03        4.0   2.472711e+03  9.712713e+01
# std        3.198562e+00        0.0   3.289733e+02  1.886670e+01
# min        2.000500e+03        4.0   1.551500e+03  2.100000e+01
# ...

# %% [markdown]
# #### Univariate Analysis

# %%
univariate_analysis(df)

# %% [markdown]
# #### Bivariant Analysis

# %%
# Grouping the DataFrame 'df' by 'PostalCode' and calculating the mean of 'TotalPremium' and 'TotalClaims'
postal_group = df.groupby('PostalCode')[['TotalPremium', 'TotalClaims']].mean()

# Displaying the first few rows of the resulting grouped DataFrame
postal_group.head()

# Performing a bivariate analysis between 'TotalPremium' and 'TotalClaims', categorized by 'PostalCode'
bivariate_analysis(df, 'TotalPremium', 'TotalClaims', 'PostalCode')

# %% [markdown]
# #### Data Comparison

# %%
#df.columns
compare_data(df)

# %% [markdown]
# #### Trends Over Geography

# %%
df.columns 
compare_trends_over_geography(df, 'Province')

# %% [markdown]
# #### Visualization

# %%
visualize_eda(df)
